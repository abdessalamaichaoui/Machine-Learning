# %% [markdown]
# * Nom : AICHAOUI
# * Prénom : Abd Essalam
# * Numéro d'étudiant : 20235493

# %% [markdown]
# ## Import the required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import os
from urllib import request
import sys
import datetime
from tqdm import tqdm
import joblib

# %matplotlib inline
sns.set_style("darkgrid")
sns.set_context("notebook")

# %%
FILE = Path('__file__').resolve()
ROOT = FILE.parents[0]  # DATA-SCUENCE-PROJECTS root directory
if ROOT.as_posix() not in sys.path:
    sys.path.append(ROOT.as_posix())  # add ROOT to PATH
# ROOT = ROOT.relative_to(Path.cwd())

# %% [markdown]
# ## Get the Data
# ### Download the Data
#
# Une approche pour obtenir cette archive (ensemble de données) consiste à utiliser nos navigateurs web pour la télécharger, puis à copier le fichier CSV dans le répertoire de notre projet. Toutefois, il est recommandé de créer une fonction simple pour effectuer cette tâche. Cela devient particulièrement utile si les données évoluent régulièrement, car nous aurons alors un petit script que nous pourrons exécuter chaque fois que nous voudrons récupérer la dernière version des données, voire même le programmer pour qu'il s'exécute automatiquement à des intervalles réguliers. L'automatisation du processus de récupération des données est également avantageuse si nous devons les installer sur plusieurs machines.

# %%
FILE_NAME = "paris_housing.csv"
DATA_URL  = "https://www.data.gouv.fr/fr/datasets/r/d72d537a-2f7f-40af-bf1a-289ee25d5ae9"
SAVE_PATH = ROOT / "datasets"

def fetch_housing_data(data_url=DATA_URL, save_path=SAVE_PATH, file_name=FILE_NAME, add_date=False):
    save_path =  Path(save_path)
    name, extension = os.path.splitext(file_name)
    save_path.mkdir(parents=True, exist_ok=True)
    date = datetime.datetime.now().strftime("%Y-%m-%d")
    try:
        request.urlretrieve(data_url, save_path / Path(name + (f'_{date}_' if add_date else "") + extension))
    except Exception as e:
        print(e)
        sys.exit()

# %%
fetch_housing_data(data_url=DATA_URL, save_path=SAVE_PATH, file_name=FILE_NAME, add_date=False)

# %%
paris_housing = pd.read_csv(SAVE_PATH / FILE_NAME, sep=';')
paris_housing.head(2)
# Out:
#    annee  id_zone  id_quartier     nom_quartier  piece     epoque  meuble_txt  \
# 0   2021       11           71      Goutte-d'Or      1  1971-1990  non meublé
# 1   2021       10           55  Petit-Montrouge      4  1946-1970      meublé
#
#     ref    max    min  ville  code_grand_quartier  \
# 0  26.0  31.20  18.20  PARIS              7511871
# 1  22.7  27.24  15.89  PARIS              7511455
#
#                                            geo_shape  \
# 0  {"coordinates": [[[2.349667597643656, 48.88373...
# 1  {"coordinates": [[[2.329136731859957, 48.83412...
#
#                             geo_point_2d
# 0   48.89213818760239,2.3555361632962777
# 1  48.826652625543865,2.3264369992248985

# %% [markdown]
# ## Examine the structure of the data
#
# Cette étape implique de fournir un aperçu succinct de la base de données, en mettant en évidence les variables de chaque échantillon (loyé d'un logement), ainsi que des informations sur les données telles que leur type, le nombre de valeurs manquantes pour chaque variable, et quelques statistiques intéressantes pour une première visualisation, telles que le nombre d'échantillons, la moyenne, le maximum, le minimum et les quartiles des variables.

# %%
paris_housing_ = paris_housing.copy()

# %%
paris_housing_.head(2)
# Out:
#    annee  id_zone  id_quartier     nom_quartier  piece     epoque  meuble_txt  \
# 0   2021       11           71      Goutte-d'Or      1  1971-1990  non meublé
# 1   2021       10           55  Petit-Montrouge      4  1946-1970      meublé
#
#     ref    max    min  ville  code_grand_quartier  \
# 0  26.0  31.20  18.20  PARIS              7511871
# 1  22.7  27.24  15.89  PARIS              7511455
#
#                                            geo_shape  \
# 0  {"coordinates": [[[2.349667597643656, 48.88373...
# 1  {"coordinates": [[[2.329136731859957, 48.83412...
#
#                             geo_point_2d
# 0   48.89213818760239,2.3555361632962777
# 1  48.826652625543865,2.3264369992248985

# %%
paris_housing_.info(), paris_housing_.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10240 entries, 0 to 10239
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   annee                10240 non-null  int64
#  1   id_zone              10240 non-null  int64
#  2   id_quartier          10240 non-null  int64
#  3   nom_quartier         10240 non-null  object
#  4   piece                10240 non-null  int64
#  5   epoque               10240 non-null  object
#  6   meuble_txt           10240 non-null  object
#  7   ref                  10240 non-null  float64
#  8   max                  10240 non-null  float64
#  9   min                  10240 non-null  float64
#  10  ville                10240 non-null  object
#  11  code_grand_quartier  10240 non-null  int64
#  12  geo_shape            10240 non-null  object
#  13  geo_point_2d         10240 non-null  object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 1.1+ MB
# ...

# %%
paris_housing_.describe()
# Out:
#               annee       id_zone   id_quartier         piece           ref  \
# count  10240.000000  10240.000000  10240.000000  10240.000000  10240.000000
# mean    2020.500000      6.662500     40.500000      2.500000     25.829805
# std        1.118089      4.224966     23.093334      1.118089      4.202257
# min     2019.000000      1.000000      1.000000      1.000000     14.300000
# 25%     2019.750000      3.000000     20.750000      1.750000     23.000000
# 50%     2020.500000      5.000000     40.500000      2.500000     25.500000
# 75%     2021.250000     11.000000     60.250000      3.250000     28.500000
# max     2022.000000     14.000000     80.000000      4.000000     39.600000
#
#                 max           min  code_grand_quartier
# count  10240.000000  10240.000000         1.024000e+04
# mean      30.996164     18.082487         7.511090e+06
# std        5.042818      2.941352         5.997236e+02
# min       17.160000     10.010000         7.510101e+06
# ...

# %%
# # Variables Qualitatives
# for col in paris_housing_.select_dtypes('object'):
#     print(f'{"="*20} {col} {"="*20}')
#     print(f'{paris_housing.loc[:, col].unique()} \n')

# %%
for col in paris_housing.select_dtypes('object'):
    print(f'{"="*20} {col} {"="*20}')
    print(paris_housing.loc[:, col].value_counts(), '\n')

# %%
paris_housing_.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
print(f"ref max = {paris_housing_.ref.max()} \nref min = {paris_housing_.ref.min()}")
# Out:
# ref max = 39.6
# ref min = 14.3

# %% [markdown]
# En observant les histogrammes, plusieurs observations peuvent être faites :
#
# Tout d'abord, les variables `ref`, `max` et `min`, qui représentent respectivement les prix de loyer de référence, les prix de loyer maximum et minimum, semblent être exprimées en euros et ne sont ni plafonnées ni échelonnées, contrairement à la plupart des bases de données. D'autre part, on peut noter que ces données ont été mises à l’échelle (une unité correspond environ à 10 000 €). Travailler sur des variables prétransformées est pratique courante en apprentissage automatique : ce n’est pas nécessairement un problème, mais nous devons essayer de comprendre comment les données ont été calculée
#
#  Les prix de loyer les plus élevés atteignent `450 000 €`, tandis que les prix de loyer les plus bas sont d'environ `100 000 €`. La distribution de ces variables suit une loi normale (gaussienne ou courbe en cloche), ce qui permet de les représenter uniquement par leur moyenne et leur variance.
#
# Les variables `annee`, `piece` et `code_grand_cartier` suivent une distribution uniforme. Cela signifie que pour chaque année, le nombre d'échantillons (logement) est le même, de même que pour chaque nombre de pièces et chaque code de grand quartier.
#
# Ces variables ont des échelles très différentes. Nous aborderons ce cas ultérieurement et discuterons du principe de normalisation. Il est également remarqué que de nombreux histogrammes sont fortement dissymétriques : ils s'étendent beaucoup plus loin à droite de la médiane qu'à gauche. Certains algorithmes d'apprentissage peuvent avoir plus de difficulté à détecter des structures dans ces cas. Par conséquent, nous tenterons de transformer ces variables afin d'obtenir une distribution plus proche d'une courbe en cloche parfaite.
#
# Bien que les graphiques donnent une représentation globale de la distribution de toutes les variables, il est particulièrement intéressant d'examiner de plus près la variable `ref`. Si nous recherchons une grande précision, nous pouvons calculer le skewness et le kurtosis de cette variable.
#
# Le skewness mesure l'asymétrie de la distribution d'une variable par rapport à la distribution normale. Un skewness positif indique une asymétrie vers la droite, tandis qu'un skewness négatif indique une asymétrie vers la gauche.
#
# Le kurtosis quantifie la forme de la distribution d'une variable en mesurant la concentration des données autour de la moyenne. Un kurtosis proche de zéro indique une distribution proche de la distribution normale, tandis qu'un kurtosis élevé indique une distribution plus concentrée (kurtosis leptokurtique) ou plus étalée (kurtosis platykurtique) par rapport à la distribution normale.
#
# Dans le cas de la variable `ref` dans le jeu de données de l'immobilier à Paris, les résultats du skewness (0.290062) indiquent une légère asymétrie vers la droite, tandis que le kurtosis (0.105049) suggère une distribution relativement proche de la distribution normale. Cela suggère que la variable `ref` suit une distribution proche d'une distribution gaussienne, ce qui peut être utile pour une analyse plus précise.

# %%
#skewness and kurtosis
print("Skewness: %f" % paris_housing_['ref'].skew())
print("Kurtosis: %f" % paris_housing_['ref'].kurt())
# Out:
# Skewness: 0.290062
# Kurtosis: 0.105049

# %% [markdown]
# ## Create a Test Set

# %% [markdown]
# Créer un jeu de test est théoriquement simple, il faut choisir au hasard certains éléments, en général 20% du jeu de données (ou moins si notre jeu de données est très grand) et les mettre de côté. Une solution consiste à sauvegarder le jeu de test lors de la première exécution, puis à le charger lors des exécutions suivantes ou bien utiliser la célèbre fonction `train_test_split` de la bibliothèque `scikit-learn` offre la possibilité de diviser des tableaux ou des matrices en sous-ensembles d'entraînement et de test aléatoires. Cette fonction offre également d'autres options pour contrôler la division du jeu de données. Nous pouvons spécifier le taux de découpage entre l'ensemble d'entraînement et l'ensemble de test, le nombre de fois où nous souhaitons mélanger les données, ainsi que la graine de génération de nombres aléatoires pour maintenir la même distribution à chaque exécution du code. Ces options nous permettent d'ajuster la manière dont les données sont réparties de manière plus précise et reproductible. Cependant, ces deux solutions ne seront plus efficaces après une mise à jour de notre jeu de données. Pour assurer une séparation stable entre les données d'entraînement et les données de test, même après la mise à jour, nous pouvez utiliser l'identifiant de chaque observation pour décider si elle doit figurer dans le jeu de test (en supposant que les observations possèdent un identifiant unique et immuable). Par exemple, nous pouvons calculer un hachage de l'identifiant de chaque observation et placer l'observation dans le jeu de test si le hachage est inférieur ou égal à 20% du hachage maximal. Ainsi, le jeu de test restera cohérent lors de toutes les exécutions, même si vous mettez à jour le jeu de données. Le nouveau jeu de test contiendra 20% des nouvelles observations ainsi que toutes celles qui faisaient déjà partie du jeu de test précédemment. Voici une possible mise en œuvre de cette approche.
#
# Mais ces solutions ne fonctionneront plus après une mise à jour de notre jeu de données. Afinn de garantir une séparation stable entre données d’entraînement et données de test même après la mise à jour du jeu de données, on peut alors utiliser l’identiant de chaque observation pour décider si celle-ci doit ou non figurer dans le jeu de test (nous supposerons que les observations ont un identificateur unique et immuable). Par exemple, nous pouvons calculer un hachage de l’identificateur de chaque observation, et mettre l’observation dans le jeu de test si le hachage est inférieur ou égal à 20% du hachage maximal. Ainsi, le jeu de test restera cohérent sur l’ensemble des exécutions, même si nous rafraîchissons le jeu de données : le nouveau jeu de test contiendra 20% des nouvelles observations, ainsi que toutes celles qui étaient déjà auparavant dans le jeu de test. Voici une possible mise en œuvre de cette approche :

# %%
from zlib import crc32

def test_set_check(id, test_rat):
    assert 0 <= test_rat <= 100, 'The rate of the parameter "test_rat" must be between [0, 100].'
    test_rat = test_rat if 0 <= test_rat <= 1 else test_rat/100
    return crc32(np.int64(id)) & 0xffffffff < test_rat * 2**32
    # return bytearray(hash(np.int64(id)).digest())[-1] < 256 * test_rat

def split_train_test(data, test_rat, by=None):
    data, by = (data.reset_index(), 'index') if by==None else (data, by) # adds an `index` column
    in_test_set = data[by].apply(lambda id_: test_set_check(id_, test_rat))
    return data.loc[~in_test_set, :], data.loc[in_test_set, :]

# %%
train_set, test_set = split_train_test(data=paris_housing_, test_rat=0.2, by=None)
train_set.shape, test_set.shape
# Out:
# ((8192, 15), (2048, 15))

# %% [markdown]
# Jusqu’ici nous ne nous sommes intéressés qu’à des méthodes d’échantillonnage purement aléatoires. C’est en général satisfaisant si notre jeu de données est assez important (avec en particulier beaucoup plus d’observations que de variables), mais si ce n’est pas le cas, nous risquons d’introduire un biais d’échantillonnage non négli-geable. Pour évaluer la qualité de l'échantillonnage, nous allons créer une nouvelle variable appelée `ref_cat` qui regroupera les prix des loyers en intervalles de 50 000€, formant ainsi sept catégories distinctes :
#     - Catégorie 1 : loyers de 10 € à 15 €
#     - Catégorie 2 : loyers de 15 € à 20 €
#     - Catégorie 3 : loyers de 20 € à 25 €
#     - Catégorie 4 : loyers de 25 € à 30 €
#     - Catégorie 5 : loyers de 30 € à 35 €
#     - Catégorie 6 : loyers de 35 € à 40 €
#     - Catégorie 7 : loyers de 40 € et plus
# Nous allons ensuite visualiser la répartition de ces catégories entre l'ensemble de données d'origine et les ensembles de données d'entraînement et de test. Pour un échantillonnage de meilleure qualité, nous souhaitons obtenir des distributions similaires par rapport à la données d'origine.

# %%
paris_housing_['ref_cat'] = pd.cut(paris_housing_['ref'],
                                  bins=[10., 15., 20., 25., 30., 35, 40, np.inf],
                                  labels=[1, 2, 3, 4, 5, 6, 7])
train_set, test_set = split_train_test(data=paris_housing_, test_rat=0.2, by=None)
train_set.shape, test_set.shape
# Out:
# ((8192, 16), (2048, 16))

# %%
sets_name = ['original_set', 'train_set', 'test_set']
fig, axes = plt.subplots(1, len(sets_name), figsize=(15, 4))
for ax, set, name in zip(axes.flatten(), [paris_housing_, train_set, test_set], sets_name):
    set.ref_cat.hist(bins=5, density=True, ax=ax)
    ax.set_title(name)

# %%
data =  {
                'original_set': paris_housing_.ref_cat.value_counts() / len(paris_housing_),
                'train_set': train_set.ref_cat.value_counts() / len(train_set),
                'test_set': test_set.ref_cat.value_counts() / len(test_set)
        }
df_ = pd.DataFrame(data=data, index=test_set.ref_cat.unique().sort_values()).sort_index().rename_axis("ref_cat", axis="index")
df_
# Out:
#          original_set  train_set  test_set
# ref_cat
# 1            0.004102   0.004150  0.003906
# 2            0.062012   0.063721  0.055176
# 3            0.385742   0.383545  0.394531
# 4            0.387988   0.387939  0.388184
# 5            0.133691   0.134155  0.131836
# 6            0.026465   0.026489  0.026367

# %% [markdown]
# Les distributions des catégories de la variable `ref_cat` montrent une grande similarité, ce qui est prometteur. Cependant, pour évaluer nos modèles de machine learning avec précision, il est préférable de les entraîner et de les tester sur des données qui représentent fidèlement la réalité du terrain. Par conséquent, il est essentiel de réaliser une division soigneuse entre les données d'entraînement et de test.
#
# Pour atteindre cet objectif, nous allons utiliser une méthode d'échantillonnage stratifié. Cette méthode nous permet de diviser nos données en ensembles d'entraînement et de test de manière stratifiée, tout en veillant à maintenir une répartition équilibrée des catégories ou classes dans les deux ensembles.
#
# En utilisant un échantillonnage stratifié, nous nous assurons que les ensembles d'entraînement et de test reflètent fidèlement la répartition des catégories de la variable `ref_cat`. Cela contribue à une meilleure représentativité des données et permet aux algorithmes d'apprentissage automatique de mieux apprendre les relations et les modèles sous-jacents.

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(paris_housing_, paris_housing_["ref_cat"]):
    strat_train_set = paris_housing_.loc[train_index]
    strat_test_set = paris_housing_.loc[test_index]

strat_train_set.shape, strat_test_set.shape
# Out:
# ((8192, 15), (2048, 15))

# %%
sets_name = ['original_set', 'train_set', 'test_set']
fig, axes = plt.subplots(1, len(sets_name), figsize=(15, 4))
for ax, set, name in zip(axes.flatten(), [paris_housing_, strat_train_set, strat_test_set], sets_name):
    set.ref_cat.hist(bins=5, density=True, ax=ax)
    ax.set_title(name)

# %%
data =  {
                'original set': paris_housing_.ref_cat.value_counts() / len(paris_housing_),
                'train_set': strat_train_set.ref_cat.value_counts() / len(strat_train_set),
                'test_set': strat_test_set.ref_cat.value_counts() / len(strat_test_set)
        }
df_ = pd.DataFrame(data=data, index=strat_test_set.ref_cat.unique().sort_values()).sort_index().rename_axis('ref_cat', axis='index')
df_
# Out:
#          original set  train_set  test_set
# ref_cat
# 1            0.004102   0.004150  0.003906
# 2            0.062012   0.062012  0.062012
# 3            0.385742   0.385742  0.385742
# 4            0.387988   0.387939  0.388184
# 5            0.133691   0.133667  0.133789
# 6            0.026465   0.026489  0.026367

# %% [markdown]
# Les distributions des catégories sont maintenant remarquablement similaires, ce qui est très satisfaisant. Nous avons consciemment accordé une attention considérable à la création de notre jeu de test, car il s'agit d'un aspect souvent négligé mais essentiel d'un projet d'apprentissage automatique. Maintenant, il est temps de passer à l'étape suivante : l'exploration des données.
#
# Cette étape nous permettra de mieux comprendre la structure, les caractéristiques et les patterns présents dans nos données, ce qui est crucial pour prendre des décisions éclairées lors de la construction de nos modèles.

# %%
# Drop "ref_cat" variable and save train and test set
for i, set_ in enumerate([strat_train_set, strat_test_set]):
    set_.drop("ref_cat", axis=1, inplace=True)
    set_.to_csv(ROOT / 'datasets' / (('strat_train_set' if i==0 else'strat_test_set') + '.csv'))
strat_train_set.shape, strat_test_set.shape
# Out:
# ((8192, 14), (2048, 14))

# %% [markdown]
# ## Discover and Visualize the Data to Gain Insights

# %% [markdown]
# Durant l'étape de découverte et de visualisation des données, il est recommandé de travailler exclusivement avec la base de données d'entraînement. Dans certains cas, la base de données d'entraînement peut être très volumineuse, ce qui rend la manipulation des données lente. Dans de telles situations, il est conseillé de travailler avec un sous-ensemble de la base d'entraînement, en veillant à ne pas toucher la base de test. La base de test doit être réservée exclusivement à l'évaluation de nos modèles de machine learning.

# %% [markdown]
# ### Visualizing Geographical Data

# %% [markdown]
# Une approche prometteuse pour répondre à ces questions serait d'utiliser une représentation géographique. Étant donné que nous disposons d'échantillons de loyers dans différentes régions, quartiers, zones, etc., il serait intéressant d'explorer la répartition des loyers sur une carte. Cela nous permettrait d'obtenir une vision d'ensemble de la localisation des zones les plus chères ou moins chères, ainsi que de comprendre les motifs ou les caractéristiques qui influencent les prix dans chaque zone. Une représentation géographique pourrait nous fournir des informations précieuses sur la structure des prix des loyers à Paris, en répondant à une partie importante des nombreuses questions que nous pourrions nous poser.
#
# Pour visualiser des données géométriques, nous utiliserons le package GeoPandas. Comme son nom l'indique, GeoPandas étend la bibliothèque de data science populaire appelée pandas en ajoutant la prise en charge des données géospatiales. Grâce à GeoPandas, nous pourrons manipuler, analyser et représenter graphiquement des données qui ont une composante géographique ou spatiale, telle que des coordonnées géographiques, des formes de polygones, des points sur une carte, etc. Cette extension nous permettra d'explorer et de visualiser facilement des informations géographiques dans nos données, ou de créer des cartes interactives pour une meilleure compréhension visuelle.
#
# La structure de données centrale dans `GeoPandas` est le `geopandas.GeoDataFrame`, une sous-classe de `pandas.DataFrame`, qui peut stocker des colonnes de géométrie et effectuer des opérations spatiales. Le `geopandas.GeoSeries`, une sous-classe de `pandas.Series`, gère les géométries. Ainsi, notre `GeoDataFrame` est une combinaison de `pandas.Series`, avec des données traditionnelles (numériques, booléennes, textuelles, etc.), et de `geopandas.GeoSeries`, avec des géométries (points, polygones, etc.). Nous pouvons avoir autant de colonnes avec des géométries que nous le souhaitons.
#
# Pour créer un `GeoDataFrame`, nous devons convertir les informations géographiques de nos données dans un format approprié. Dans notre cas, nous avons des coordonnées de latitude et de longitude sous forme de chaînes de caractères. Afin de les rendre exploitables par GeoPandas, nous devons effectuer un prétraitement.
#
# Tout d'abord, nous devons convertir les valeurs de latitude et de longitude en type de données `float64`. Cela peut être fait en utilisant la fonction `astype()` de Pandas pour convertir les colonnes correspondantes en flottants.
#
# Ensuite, pour créer la géométrie des zones, nous devons représenter les polygones sous la forme `POLYGON`. Pour cela, nous devons extraire les informations nécessaires de nos données, telles que les coordonnées des points qui définissent les limites des zones. En utilisant ces coordonnées, nous pouvons créer des objets `Polygon` à l'aide de la bibliothèque Shapely.
#
# Une fois que nous avons obtenu les coordonnées des polygones pour chaque zone, nous pouvons créer une colonne `geometry` dans notre DataFrame d'origine et y stocker les objets `Polygon` correspondants.
#
# En effectuant ces prétraitements, nous serons en mesure de créer un `GeoDataFrame` avec la variable `geometry` correctement définie, ce qui nous permettra d'effectuer des analyses géospatiales et de visualiser les données sur une carte.

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import shapely.geometry
import json

# %%
housing = strat_train_set.copy()

# %%
# Create 'longitude' and 'latitude' columns
housing[['longitude', 'latitude']] = housing['geo_point_2d'].str.split(',', expand=True).astype(float)

# Convert 'geo_shape' column to geometry
housing['geometry'] = housing['geo_shape'].apply(json.loads).apply(shapely.geometry.shape)

# Create GeoDataFrame with the necessary columns
gdf = geopandas.GeoDataFrame(housing, geometry='geometry', crs='EPSG:4326')

# Calculate the area of each geographical entity
gdf['area'] = gdf.geometry.area

# Calculate the boundary of each geographical entity
gdf['boundary'] = gdf.geometry.boundary

# Calculate the centroid of each geographical entity
gdf['centroid'] = gdf.geometry.centroid

# Display the 'area', 'boundary', and 'centroid' columns
# area_values = gdf['area']
# boundary_values = gdf['boundary']
# centroid_values = gdf['centroid']

gdf.head(5)
# Out:
# C:\Users\Brani\AppData\Local\Temp\ipykernel_25576\2948103623.py:11: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['area'] = gdf.geometry.area
# C:\Users\Brani\AppData\Local\Temp\ipykernel_25576\2948103623.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['centroid'] = gdf.geometry.centroid
#       annee  id_zone  id_quartier   nom_quartier  piece      epoque  \
# 2840   2022       14           45        Bel-Air      4  Avant 1946
# 755    2020       11           43       Roquette      4   1971-1990
# 315    2022       13           80       Charonne      3   1946-1970
# 138    2019        4           14  Saint-Gervais      2  Avant 1946
# ...

# %% [markdown]
# Maintenant que nous disposons des variables nécessaires, nous allons visualiser nos données géométriques à l'aide de la méthode `plot` de `GeoPandas`. Cette visualisation ne vise pas à montrer les belles rues de Paris ou la tour Eiffel. En revanche, nous pouvons découper Paris en petites zones et visualiser, par exemple, les prix des loyers dans une zone donnée, la population, etc. Cela nous permettra d'explorer et d'analyser des aspects spécifiques de Paris à l'échelle géographique, offrant ainsi des informations plus détaillées et des perspectives intéressantes.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
gdf.plot(column="area", legend=True, cmap ='viridis', ax=ax,  legend_kwds={'label': 'area'}) # 'Reds'
ax.set_title('Paris according to surface area')
# Out:
# Text(0.5, 1.0, 'Paris according to surface area')

# %% [markdown]
# Cette représentation décrit les zones de Paris en fonction de leur surface. Elle offre une vue magnifique et nous permet d'obtenir plusieurs informations à partir de ce type de représentation. Par conséquent, la variable qui nous intéresse dans ce projet est `ref` (le prix du loyer référent). Nous pouvons désormais visualiser le prix du loyer en fonction de la zone géographique. Cela nous permettra d'explorer et de visualiser les relations et les tendances entre différentes variables, ce qui peut être très utile pour une analyse approfondie de notre jeu de données.
#
# En plus de représenter les prix du loyer en fonction des zones, nous allons également examiner le nombre d'échantillons par zone et par quartier. Cela nous permettra d'avoir une idée de la population des quartiers et des zones à Paris, une information qui n'est pas incluse dans le jeu de données mais qui est très importante pour l'estimation du prix du loyer. En analysant ces données supplémentaires, nous pourrons mieux comprendre les facteurs qui influencent les prix du loyer et faire des observations intéressantes sur la relation entre la population et les prix dans différentes zones et quartiers de Paris.

# %%
name_columns = ['ref', 'id_zone', 'id_quartier']
titles = ['', '', '']
fig, axes = plt.subplots(1, len(name_columns), figsize=(20, 6))

for ax, col, title in zip(axes.flatten(), name_columns, titles):
    gdf.plot(ax=ax, column=col, cmap='viridis', legend=True, # 'plasma'
            legend_kwds={'shrink': 0.8, # reduce the size of the color bar
                        'label': col, # add a title to the color bar
                        'format': '%.0f',
                        'orientation': 'horizontal'}) # format the values of the color bar)
    # gdf["centroid"].plot(ax=ax, color="black", markersize=gdf.ref)
    # ax.set_title(title)

# %% [markdown]
# Nous pouvons conclure que la population est plus élevée dans l'est de Paris, notamment dans les 20ème, 19ème, 12ème et 11ème arrondissements. Cependant, les prix du loyer y sont moins chers. En revanche, dans l'ouest de Paris, notamment dans les 16ème, 15ème, 8ème et 7ème arrondissements, la population est moins dense, mais les prix du loyer sont très élevés. En ce qui concerne le centre de Paris, les arrondissements 1, 2, 3, 4 et 5 sont également moins peuplés, mais les prix du loyer y sont exorbitants. Cette observation met en évidence la corrélation complexe entre la population, la localisation géographique et les prix du loyer à Paris.
#
# Cette analyse serait encore plus perspicace et précise si nous disposions des pourcentages de population pour chaque zone. Cependant, en tant que data scientist, notre rôle est de trouver des astuces et des techniques pour explorer les données et en extraire des informations, même en l'absence de données directes ou complètes. Nous pouvons utiliser des méthodes indirectes telles que l'analyse des variables disponibles, la corrélation avec d'autres facteurs socio-économiques ou la segmentation de la population en fonction d'autres critères. L'objectif est de tirer le meilleur parti des données dont nous disposons et de fournir des insights pertinents malgré les limitations.

# %% [markdown]
# ### Search for correlations

# %% [markdown]
# Étant donné que le jeu de données est de taille raisonnable, nous pouvons facilement calculer le coefficient de corrélation (également appelé coefficient de corrélation de Pearson) entre chaque paire de variables en utilisant la méthode `corr()` de `pandas`. Cette mesure statistique permet d'évaluer la relation linéaire entre deux variables et fournit une indication de l'intensité et de la direction de cette relation. En calculant les coefficients de corrélation, nous pourrons déterminer si les variables sont positivement ou négativement corrélées, ainsi que l'intensité de cette corrélation. Cette analyse nous permettra de mieux comprendre les relations entre les différentes variables de notre jeu de données et d'identifier d'éventuels motifs ou tendances.

# %%
gdf.annee = pd.to_datetime(gdf.annee)
corr_matrix = gdf.corr()
corr_matrix.head(len(corr_matrix.columns))
# Out:
# C:\Users\Brani\AppData\Local\Temp\ipykernel_25576\3944519847.py:2: FutureWarning: The default value of numeric_only in GeoDataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = gdf.corr()
#                       id_zone  id_quartier     piece       ref       max  \
# id_zone              1.000000     0.696841  0.004329 -0.552088 -0.552201
# id_quartier          0.696841     1.000000  0.005190 -0.407268 -0.407390
# piece                0.004329     0.005190  1.000000 -0.552808 -0.552699
# ref                 -0.552088    -0.407268 -0.552808  1.000000  0.999996
# max                 -0.552201    -0.407390 -0.552699  0.999996  1.000000
# min                 -0.552227    -0.407443 -0.552844  0.999987  0.999988
# code_grand_quartier  0.694710     0.998905  0.005160 -0.407326 -0.407448
# longitude           -0.009139     0.178669 -0.005938 -0.062120 -0.062164
# ...

# %%
corr_matrix.ref.sort_values()
# Out:
# piece                 -0.552808
# id_zone               -0.552088
# code_grand_quartier   -0.407326
# id_quartier           -0.407268
# latitude              -0.335569
# area                  -0.197255
# longitude             -0.062120
# min                    0.999987
# max                    0.999996
# ref                    1.000000
# Name: ref, dtype: float64

# %% [markdown]
# Il est important de noter que la méthode `pandas.corr()` calcule les corrélations entre les variables quantitatives de notre jeu de données. Dans notre dataset, nous avons 11 variables quantitatives, y compris la variable `ref`. Bien que nous puissions observer des corrélations positives et négatives significatives, il est essentiel de se poser la question suivante : est-ce que la corrélation entre les variables `a` et `b` a un sens réel et, plus important encore, quelles variables sont réellement pertinentes lors de l'achat d'un bien immobilier ?
#
# En examinant les variables telles que `id_zone`, `code_grand_quartier` et `id_quartier`, il est difficile de trouver une signification pertinente, car leurs augmentations ou diminutions n'ont pas d'impact direct sur le prix du loyer. Cependant, ces variables pourraient potentiellement être utilisées pour estimer la population de chaque région, ce qui pourrait ensuite nous aider à prédire les prix du loyer.
#
# En revanche, les variables telles que le `piece`, la `area`, la `longitude` et la `latitude` semblent être de bons indicateurs du prix du loyer. Elles sont plus directement liées aux caractéristiques physiques du bien immobilier.
#
# Quant aux valeurs minimales et maximales, elles semblent être redondantes avec la valeur `ref`, simplement décalées vers la gauche pour la valeur minimale (correspondant aux loyers moins chers) et vers la droite pour la valeur maximale (correspondant aux loyers plus chers).

# %% [markdown]
# Une autre approche pour examiner les corrélations entre les variables consiste à utiliser la fonction `scatter_matrix` de pandas, qui permet de croiser deux à deux toutes les variables quantitatives (c'est-à-dire numériques). Étant donné qu'il y a maintenant 11 variables quantitatives, cela générerait un total de 11 * 11 = 121 graphiques, ce qui ne tiendrait pas sur une seule page. Par conséquent, concentrons-nous uniquement sur quelques variables prometteuses qui semblent être les plus corrélées à la valeur médiane des habitations.
#
# En sélectionnant les variables les plus pertinentes, nous pourrons examiner plus en détail leur corrélation avec la valeur `ref` des loyers. Cela nous donnera une idée plus précise de la relation entre ces variables et le prix des logements.

# %%
from pandas.plotting import scatter_matrix

attributes = ["ref", "longitude", "latitude", "area", "piece"]
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='ref', ylabel='ref'>,
#         <Axes: xlabel='longitude', ylabel='ref'>,
#         <Axes: xlabel='latitude', ylabel='ref'>,
#         <Axes: xlabel='area', ylabel='ref'>,
#         <Axes: xlabel='piece', ylabel='ref'>],
#        [<Axes: xlabel='ref', ylabel='longitude'>,
#         <Axes: xlabel='longitude', ylabel='longitude'>,
#         <Axes: xlabel='latitude', ylabel='longitude'>,
#         <Axes: xlabel='area', ylabel='longitude'>,
#         <Axes: xlabel='piece', ylabel='longitude'>],
#        [<Axes: xlabel='ref', ylabel='latitude'>,
#         <Axes: xlabel='longitude', ylabel='latitude'>,
#         <Axes: xlabel='latitude', ylabel='latitude'>,
#         <Axes: xlabel='area', ylabel='latitude'>,
#         <Axes: xlabel='piece', ylabel='latitude'>],
#        [<Axes: xlabel='ref', ylabel='area'>,
#         <Axes: xlabel='longitude', ylabel='area'>,
#         <Axes: xlabel='latitude', ylabel='area'>,
#         <Axes: xlabel='area', ylabel='area'>,
# ...

# %%
gdf.nunique(), gdf.shape
# Out:
# (annee                    4
#  id_zone                 14
#  id_quartier             80
#  nom_quartier            80
#  piece                    4
#  epoque                   4
#  meuble_txt               2
#  ref                    212
#  max                    327
#  min                    308
#  ville                    1
#  code_grand_quartier     80
#  geo_shape               80
#  geo_point_2d            80
#  longitude               80
#  latitude                80
#  geometry                80
#  area                    80
#  boundary                80
#  centroid                80
#  dtype: int64,
#  (8192, 20))

# %% [markdown]
# Ce graphique met en évidence plusieurs observations intéressantes. Tout d'abord, il convient de noter que les variables `longitude`, `latitude`, `area` et `piece` sont représentées pour chaque zone ou région de Paris, et non pour chaque logement individuel. La vérification de cette distinction aurait pu être effectuée dès le début de l'analyse en posant directement la question aux auteurs de la dataset ou en lisant sa description, le cas échéant. En examinant attentivement les graphiques de dispersion, nous, en tant que data scientist, avons remarqué que chaque ligne du dataframe correspond à un logement situé dans une région spécifique, et qu'il y a plusieurs logements dans la même région. Au total, nous avons recensé 10240 logements répartis dans 80 régions, grâce aux informations fournies par le graphique de dispersion.
#
# De plus, une corrélation évidente se dégage entre les variables `longitude`, `latitude`, `area`, `piece` et le prix de référence (`ref`). Les tendances croissantes et décroissantes de ces variables par rapport au prix de référence sont clairement visibles. De plus, les points de données ne sont pas trop dispersés, ce qui n'est pas le cas pour la variable `piece`. Cette observation est tout à fait compréhensible, car la variable `piece` ne possède que quatre valeurs uniques, à savoir 1, 2, 3 et 4.
#
# Nous avons la possibilité d'explorer et de créer de nouvelles variables à partir des données disponibles dans notre dataframe. Parmi les variables que nous pourrions considérer, il y a le nombre de personnes par logement, la population totale, le nombre de logements et la densité de population, ect. Il est également possible d'envisager d'autres variables, comme le salaire moyen des individus, mais cela nécessiterait de collecter des données supplémentaires ou de faire appel à des experts du domaine pour obtenir des estimations précises.
#
# Cependant, dans notre cas, nous nous limiterons aux données dont nous disposons actuellement et nous chercherons à créer et à adapter nos modèles en fonction de cette base de données. Nous pouvons explorer les relations entre les variables existantes, identifier les corrélations et les tendances, et utiliser ces informations pour améliorer notre compréhension et nos prédictions.

# %% [markdown]
# ### Relationship with numerical variables

# %% [markdown]
# Afin de mieux comprendre la relation entre les variables du jeu de données et la variable cible `ref`, nous allons effectuer une analyse détaillée en représentant graphiquement les variables quantitatives et qualitatives en fonction de `ref`. Cette approche nous permettra de mieux observer les tendances, les corrélations et les éventuelles différences entre les différentes valeurs de `ref`. Nous examinerons les distributions, les relations linéaires ou non linéaires, ainsi que les variations de comportement des variables par rapport à `ref`. Cette analyse approfondie nous aidera à mieux appréhender l'influence des différentes variables sur la variable cible et à identifier d'éventuelles tendances ou modèles significatifs.

# %%
gdf['meuble_bool'] = gdf.meuble_txt.map({'non meublé': 0, 'meublé': 1})

# %%
fig, axes = plt.subplots(2, 1, figsize=(15, 12))
ax1, ax2 = axes.flatten()

# barplot
mean_prices = gdf.groupby(['id_zone', 'meuble_txt'])['ref'].mean().reset_index()
sns.barplot(data=mean_prices, x='id_zone', y='ref', hue="meuble_txt", ax=ax1)
ax1.set_xlabel('Zone')
ax1.set_ylabel('Prix des loyers (moyenne)')
ax1.set_title('Moyenne des prix des loyers par zone')

# boxplot
sns.boxplot(data=gdf, x="id_zone", y="ref", hue="meuble_txt", ax=ax2)
ax2.set_xlabel('Zone')
ax2.set_ylabel('Prix des loyers')
ax2.set_title('Distribution des prix des loyers par zone')
# Out:
# Text(0.5, 1.0, 'Distribution des prix des loyers par zone')

# %%
# fig, axes = plt.subplots(2, 1, figsize=(15, 12))
# ax1, ax2 = axes.flatten()

# # # barplot
# mean_prices = gdf.groupby(['id_zone', 'nom_quartier'])['ref'].mean().reset_index()
# sns.barplot(data=mean_prices, x='nom_quartier', y='ref', hue='id_zone', ax=ax1)
# ax1.set_xlabel('Quartier')
# ax1.set_ylabel('Prix des loyers (moyenne)')
# ax1.set_title('Moyenne des prix des loyers par quartier et par zone')

# # boxplot
# sns.boxplot(data=gdf, x="nom_quartier", y="ref", hue="meuble_txt", ax=ax2)
# ax2.set_xlabel('Zone')
# ax2.set_ylabel('Prix des loyers')
# ax2.set_title('Distribution des prix des loyers par zone')

# %%
fig, axes = plt.subplots(2, 1, figsize=(15, 12))
ax1, ax2 = axes.flatten()

# barplot
sns.boxplot(data=gdf, x='piece', y='ref', hue='meuble_txt', ax=ax1)
ax1.set_xlabel('Nombre de pièces')
ax1.set_ylabel('Prix des loyers (référents)')
ax1.set_title('Comparaison des prix des loyers (meublés/non meublés) selon le nombre de pièces')

# boxplot
sns.lineplot(data=gdf, x="piece", y="ref", hue="meuble_txt", ax=ax2)
ax2.set_xlabel('Nombre de pièces')
ax2.set_ylabel('Prix des loyers (référents)')
ax2.set_title('Tendance des prix des loyers (meublés/non meublés) en fonction du nombre de pièces')
# Out:
# Text(0.5, 1.0, 'Tendance des prix des loyers (meublés/non meublés) en fonction du nombre de pièces')

# %%
# fig, axes = plt.subplots(2, 1, figsize=(15, 12))
# ax1, ax2 = axes.flatten()

# # barplot
# sns.boxplot(data=gdf, x='epoque', y='ref', hue='meuble_txt', ax=ax1)
# ax1.set_xlabel('Époque de construction de la zone')
# ax1.set_ylabel('Prix des loyers (référents)')
# ax1.set_title('Comparaison des prix des loyers (meublés/non meublés) selon l\'époque de construction de la zone')

# # boxplot
# mean_prices_epoque = gdf.groupby(['epoque', 'meuble_txt'])['ref'].mean().reset_index()
# sns.lineplot(data=mean_prices_epoque, x="piece", y="ref", hue="meuble_txt", ax=ax2)
# ax2.set_xlabel('Nombre de pièces')
# ax2.set_ylabel('Prix des loyers référents')
# ax2.set_title('Moyenne des prix des loyers (meublés/non meublés) par époque de construction de la zone')


# # Graphique en boîte et moustaches pour comparer les prix des loyers selon l'époque de construction de la zone
# plt.figure(figsize=(10, 6))
# sns.boxplot(x='epoque', y='prix_loyer', data=df)
# plt.xlabel('Époque de construction de la zone')
# plt.ylabel('Prix des loyers référents (moyenne)')
# plt.title('Comparaison des prix des loyers selon l\'époque de construction de la zone')
# plt.show()

# # Calculer la moyenne des prix des loyers par époque
# mean_prices_epoque = df.groupby('epoque')['prix_loyer'].mean().reset_index()

# # Graphique en barres pour représenter la moyenne des prix des loyers par époque
# plt.figure(figsize=(10, 6))
# sns.barplot(x='epoque', y='prix_loyer', data=mean_prices_epoque)
# plt.xlabel('Époque de construction de la zone')
# plt.ylabel('Prix des loyers (moyenne)')
# plt.title('Moyenne des prix des loyers par époque de construction de la zone')
# plt.show()
